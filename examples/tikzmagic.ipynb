# %%
#%install_ext http://www.ipp.mpg.de/~mkraus/python/tikzmagic.py
#%load_ext tikzmagic
#%tikz \draw (0,0) rectangle (1,1);

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle,Arrow

plt.xkcd()
fig, ax = plt.subplots(ncols=1, figsize=(16,6))
ax.set_xlim((1,18)); ax.set_ylim((0,6))
ax.set_xticks([]); ax.set_yticks([])
#map(lambda s: ax.spines[s].set_color('none'), ['top','right','bottom','left'])
y = 4
r = .8
pos = [(3,y),(6,y),(9,y),(12,y),(15,y)]
text = ['s0','s1','s2','s3','s4']
circ = [Circle(p,radius=r,fill=False,lw=1.) for p in pos]
map(ax.add_patch, circ)
map(lambda p,s: ax.text(p[0]-.1,p[1],s,size='large'), pos, text)
arrstyle1 = dict(arrowstyle='->',connectionstyle="arc3,rad=-1.",shrinkA=50,shrinkB=50)
ax.annotate('', xy=pos[1], xytext=pos[0], size=40, arrowprops=arrstyle1)
ax.annotate('', xy=pos[2], xytext=pos[1], size=40, arrowprops=arrstyle1)
ax.annotate('', xy=pos[3], xytext=pos[2], size=40, arrowprops=arrstyle1)
ax.annotate('', xy=pos[4], xytext=pos[3], size=40, arrowprops=arrstyle1)
ax.annotate('', xy=pos[0], xytext=pos[4], size=40, arrowprops=
                dict(arrowstyle='->',connectionstyle="arc3,rad=-.65",shrinkA=50,shrinkB=50))
ax.annotate('', xy=pos[0], xytext=pos[3], size=40, arrowprops=
                dict(arrowstyle='->',connectionstyle="arc3,rad=-.6",shrinkA=50,shrinkB=50))
ax.annotate('', xy=pos[0], xytext=pos[2], size=40, arrowprops=
                dict(arrowstyle='->',connectionstyle="arc3,rad=-.5",shrinkA=50,shrinkB=50))
ax.annotate('', xy=pos[0], xytext=pos[1], size=40, arrowprops=
                dict(arrowstyle='->',connectionstyle="arc3,rad=-.4",shrinkA=50,shrinkB=50))

# %%
# Out:
# No image generated.
